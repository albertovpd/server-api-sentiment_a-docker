# %%
from populate import connectCollection
import json

db, coll = connectCollection('project2911','chats_sentiment_analysis')

with open('chats.json') as f:

    chats_json = json.load(f)

coll.insert_many(chats_json)

# %%
#data=list(coll.find({}))

# %%
#data
# Out:
# [{'_id': ObjectId('5de15fbde62d1775c4a549a6'),
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 0,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:15:41',
#   'text': 'Hey Mike, whats up??'},
#  {'_id': ObjectId('5de15fbde62d1775c4a549a7'),
#   'idUser': 1,
#   'userName': 'Mike Wazowski',
#   'idMessage': 1,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:16:59',
#   'text': 'Dude!!! 😀️ Did you watch the game last night?'},
#  {'_id': ObjectId('5de15fbde62d1775c4a549a8'),
#   'idUser': 0,
#   'userName': 'John Wick',
#   'idMessage': 2,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:17:31',
#   'text': 'No, had to work. How was it?'},
#  {'_id': ObjectId('5de15fbde62d1775c4a549a9'),
#   'idUser': 1,
#   'userName': 'Mike Wazowski',
#   'idMessage': 3,
#   'idChat': 0,
#   'datetime': '2019-10-17 10:18:41',
#   'text': 'Awesome! Boyander scored 3 goals!'},
#  {'_id': ObjectId('5de15fbde62d1775c4a549aa'),
#   'idUser': 0,
#   'userName': 'John Wick',
# ...
